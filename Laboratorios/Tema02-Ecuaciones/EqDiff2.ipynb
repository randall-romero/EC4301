# %% [markdown]
# <img src="escuela-de-economia.png" width="260" height="60">
# <center>
#     <b>EC4301 MACROECONOMETRÍA</b><br>
#     <b>Profesor:  Randall Romero Aguilar, PhD</b>
# <br><br>
# <b>Laboratorio:</b>
# <div style="font-size:175%;color:white; background-color: #0064b0;">Tema 2: Ecuaciones en diferencia</div>
# <div style="font-size:250%;color:white; background-color: #0064b0;">Resolviendo una ecuación con sympy</div>
# </center>
# <i>Creado:     2020-Ene-16
#     <br>
#     Actualizado: 2020-Sep-08</i>

# %% [markdown]
# ## Resolviendo una ecuación en diferencia con sympy
#
# Este cuaderno resuelve la ecuación en diferencia
# \begin{equation}
# y_t = 0.9y_{t-1} -0.2y_{t-2} + 3
# \end{equation}
# que está incluida en **Handout-02--Ecuaciones-en-diferencia.pdf**

# %%
import numpy as np
from sympy import Function, rsolve
from sympy.abc import t
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')

y = Function('y')

# %% [markdown]
# ## Solución analítica

# %% [markdown]
# ### Solución ecuación homogénea

# %%
rsolve(y(t) - 0.9*y(t-1) + 0.2*y(t-2), y(t))
# Out:
# 0.4**t*C0 + 0.5**t*C1

# %% [markdown]
# ### Solución general

# %%
rsolve(y(t) - 0.9*y(t-1) + 0.2*y(t-2) - 3, y(t))
# Out:
# 0.4**t*C0 + 0.5**t*C1 + 10.0

# %% [markdown]
# ### Solución general con condiciones iniciales

# %%
z = rsolve(y(t) - 0.9*y(t-1) + 0.2*y(t-2) - 3, y(t), {y(0):13, y(1): 11.3})
z
# Out:
# 2.0*0.4**t + 1.0*0.5**t + 10.0

# %%
tt = np.arange(13)
plt.plot(tt, 2*0.4**tt+0.5**tt+10, 'ro-', markersize=12)

# %% [markdown]
# ## Solución recursiva a partir de condiciones iniciales

# %%
T = 13
Y = np.zeros(T)
Y[:2] = 13, 11.3


for t in range(2, T):
    Y[t] = 0.9*Y[t-1]-0.2*Y[t-2] + 3

plt.plot(Y,'ro-', markersize=12)
